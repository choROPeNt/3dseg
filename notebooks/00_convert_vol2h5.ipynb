# %%
import os
import h5py 
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = "/Volumes/DataEx/BIAX_Duereth/Gewebe_245_30mmStempel/Gewebe_245_30mmStempel_00/Gewebe_245_30mmStempel_00.vol"


assert os.path.exists(file_path)

# %%
dtype = np.float32
shape = [3100,3100,600]

# %%
try:
    with open(file_path, 'rb') as f:
        raw_data = np.fromfile(f, dtype=dtype)
        print("succeeded")
        # If you have a specific shape, reshape the array accordingly
        if shape:
            raw_data = raw_data.reshape(shape)
except FileNotFoundError:
    print(f"File  '{file_path}' not found.")
    raw_data = None
# Out:
# succeeded

# %%
raw_data = raw_data.reshape([600,3100,3100])

# %%
plt.imshow(raw_data[:,:,1500])
