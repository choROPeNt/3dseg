# %%
import os
import numpy as np
import nibabel as nib
import h5py
import pydicom as dicom
import matplotlib.pylab as plt

# %% [markdown]
# # load data

# %%
seg = nib.load(os.path.join('..','data','rsna-2022-cervical-spine-fracture-detection','train_images','1.2.826.0.1.3680043.780.nii'))


seg_data = np.rot90(seg.get_data())
# Out:
# C:\Users\dchristi\AppData\Local\Temp\ipykernel_14748\1736917424.py:4: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   seg_data = np.rot90(seg.get_data())

# %%
plt.imshow(seg_data[:,:,0])

# %%
DCIMpath = os.path.join('..','data','BIIAX')

# %%
raw = np.empty_like(seg_data)

for n, file in enumerate(os.walk(image_path)):
    ds = dicom.dcmread(image_path)
    
    raw[:,:,n] = ds.pixel_array
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\dchristi\Documents\Projekte\MachineLearning\3dseg\notebooks\RSNA_dataset.ipynb Zelle 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dchristi/Documents/Projekte/MachineLearning/3dseg/notebooks/RSNA_dataset.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> raw = np.empty_like(seg_data)
#       <a href='vscode-notebook-cell:/c%3A/Users/dchristi/Documents/Projekte/MachineLearning/3dseg/notebooks/RSNA_dataset.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> for n, file in enumerate(os.walk(image_path)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dchristi/Documents/Projekte/MachineLearning/3dseg/notebooks/RSNA_dataset.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     ds = dicom.dcmread(image_path)
# ...

# %%
plt.imshow(ds.pixel_array)
