# %%
import os 
import numpy as np
import nrrd
import matplotlib.pyplot as plt

# %%
data, header = nrrd.read('Segmentation08_05_23.nrrd')

# %%
for key in header.keys():
    print(key)
# Out:
# type
# dimension
# space
# sizes
# space directions
# kinds
# endian
# encoding
# space origin
# Segment0_Color
# Segment0_ColorAutoGenerated
# Segment0_Extent
# Segment0_ID
# Segment0_LabelValue
# Segment0_Layer
# Segment0_Name
# Segment0_NameAutoGenerated
# Segment0_Tags
# Segment1_Color
# Segment1_ColorAutoGenerated
# Segment1_Extent
# Segment1_ID
# Segment1_LabelValue
# Segment1_Layer
# Segment1_Name
# Segment1_NameAutoGenerated
# Segment1_Tags
# Segment2_Color
# Segment2_ColorAutoGenerated
# Segment2_Extent
# Segment2_ID
# Segment2_LabelValue
# Segment2_Layer
# Segment2_Name
# Segment2_NameAutoGenerated
# Segment2_Tags
# Segmentation_ContainedRepresentationNames
# Segmentation_ConversionParameters
# Segmentation_MasterRepresentation
# Segmentation_ReferenceImageExtentOffset

# %%
header['sizes']
# Out:
# array([ 990, 1012,  993])

# %%
data.shape
# Out:
# (990, 1012, 993)

# %%
plt.imshow(data[:,:,1])
